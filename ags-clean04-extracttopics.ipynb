# %%
# %load_ext sql
# %sql mysql://sywang@localhost/?charset=utf8mb4

# %%
database = 'sywang_project' ## THIS IS YOUR SUNETID
msgs_table = 'msgs'
topics_cp_table = 'ags_cp'
topics_freq_table = 'ags_freq'

# %%
# %sql use {database}
# Out:
#  * mysql://sywang@localhost/?charset=utf8mb4
# 0 rows affected.
# []

# %% [markdown]
# # Extract topics, by user, from the 1-gram tables

# %%
# !dlatkInterface.py \
    --corpdb {database} \
    --corptable msgs \
    --correl_field user_id \
    --lexicondb {database} \
    --add_lex_table -l {topics_cp_table} --weighted_lexicon
# Out:
# /shared/anaconda3/lib/python3.7/site-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.linear_model.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.linear_model. Anything that cannot be imported from sklearn.linear_model is now part of the private API.
#   warnings.warn(message, FutureWarning)
# /shared/anaconda3/lib/python3.7/site-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.feature_selection.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.feature_selection. Anything that cannot be imported from sklearn.feature_selection is now part of the private API.
#   warnings.warn(message, FutureWarning)
#
#
# -----
# DLATK Interface Initiated: 2020-11-16 06:53:23
# -----
# SQL QUERY: SELECT * FROM sywang_project.ags_cp
# ...

# %% [markdown]
# this creates the topics table
# feat$cat_ags_cp_w$msgs$user_id$1gra

# %%
feat_topics_table = 'feat$cat_ags_cp_w$msgs$user_id$1gra'

# %%
# %%sql
# select feat, sum(group_norm)/398 as popularity from {feat_topics_table}
# group by feat
# order by popularity desc
# limit 10
# Out:
#  * mysql://sywang@localhost/?charset=utf8mb4
# 10 rows affected.
# [('_intercept', 1.0),
#  ('29', 0.016369938879875517),
#  ('16', 0.013623617191025875),
#  ('19', 0.013533974481477598),
#  ('0', 0.011640597280189062),
#  ('1', 0.011244759020684966),
#  ('2', 0.010610960133728229),
#  ('35', 0.01003618425463437),
#  ('7', 0.009936567539457323),
#  ('38', 0.009685352017105502)]

# %%
# %%sql
# use {database};
# select category, group_concat(term order by weight desc separator ', ') as top_words from (
#     select category, term, weight,
#     @num := if(@type = category, @num + 1, 1) as row_number,
#     @type := category as dummy
#     from {topics_freq_table}
#     order by category, weight desc
# ) as x where x.row_number <= 10
# group by category
# having category like "29" or category like "16"  or category like "19" or category like "0" or category like "1";
# Out:
#  * mysql://sywang@localhost/?charset=utf8mb4
# 0 rows affected.
# 5 rows affected.
# [('0', 'practice, contact, interested, full, clinic, care, opportunity, email, position, feel'),
#  ('1', 'year, advice, history, thoughts, cell, beach, meds, slt, months, presented'),
#  ('16', 'tube, technique, good, sclera, cornea, scleral, conj, luck, patch, graft'),
#  ('19', 'glaucoma, patient, specialist, recommendations, moving, area, center, dear, cataract, recommend'),
#  ('29', 'iop, years, ago, weeks, back, ahmed, week, bleb, post, retina')]

# %% [markdown]
# # Extract topics, by all message, from the 1-gram tables

# %%
# !dlatkInterface.py \
    --corpdb {database} \
    --corptable msgs \
    --correl_field message_id \
    --lexicondb {database} \
    --add_lex_table -l {topics_cp_table} --weighted_lexicon
# Out:
# /shared/anaconda3/lib/python3.7/site-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.linear_model.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.linear_model. Anything that cannot be imported from sklearn.linear_model is now part of the private API.
#   warnings.warn(message, FutureWarning)
# /shared/anaconda3/lib/python3.7/site-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.feature_selection.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.feature_selection. Anything that cannot be imported from sklearn.feature_selection is now part of the private API.
#   warnings.warn(message, FutureWarning)
#
#
# -----
# DLATK Interface Initiated: 2020-11-16 06:53:51
# -----
# SQL QUERY: SELECT * FROM sywang_project.ags_cp
# ...

# %% [markdown]
# this creates the topics table
# feat$cat_ags_cp_w$msgs$message_id$1gra

# %%
feat_topics_table = 'feat$cat_ags_cp_w$msgs$message_id$1gra'

# %%
# %%sql
# select feat, sum(group_norm)/1908 as popularity from {feat_topics_table}
# group by feat
# order by popularity desc
# limit 10
# Out:
#  * mysql://sywang@localhost/?charset=utf8mb4
# 10 rows affected.
# [('_intercept', 1.0),
#  ('16', 0.014534076114026153),
#  ('29', 0.014434612216371217),
#  ('10', 0.012136173771889051),
#  ('35', 0.011453994156584463),
#  ('2', 0.011318366471513203),
#  ('20', 0.010558412555087642),
#  ('30', 0.010389023943702717),
#  ('36', 0.01017775156965893),
#  ('5', 0.00982265532684183)]

# %%
# %%sql
# use {database};
# select category, group_concat(term order by weight desc separator ', ') as top_words from (
#     select category, term, weight,
#     @num := if(@type = category, @num + 1, 1) as row_number,
#     @type := category as dummy
#     from {topics_freq_table}
#     order by category, weight desc
# ) as x where x.row_number <= 10
# group by category
# having category like "16" or category like "29"  or category like "10" or category like "35" or category like "2";
# Out:
#  * mysql://sywang@localhost/?charset=utf8mb4
# 0 rows affected.
# 5 rows affected.
# [('2', 'angle, cataract, closure, iris, lens, open, case, eyes, clear, anterior'),
#  ('10', 'glaucoma, daniel, advanced, treated, eyecare, https://youtu.be, specialist, president, laroche, www.advancedeyecareny.com'),
#  ('16', 'tube, technique, good, sclera, cornea, scleral, conj, luck, patch, graft'),
#  ('29', 'iop, years, ago, weeks, back, ahmed, week, bleb, post, retina'),
#  ('35', "iris, i've, experience, agree, angle, work, luck, cut, phaco, easily")]

# %% [markdown]
# # Extract topics, by all threadheads, from the 1-gram tables

# %%
# !dlatkInterface.py \
    --corpdb {database} \
    --corptable threadheads \
    --correl_field thread_id \
    --lexicondb {database} \
    --add_lex_table -l {topics_cp_table} --weighted_lexicon
# Out:
# /shared/anaconda3/lib/python3.7/site-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.linear_model.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.linear_model. Anything that cannot be imported from sklearn.linear_model is now part of the private API.
#   warnings.warn(message, FutureWarning)
# /shared/anaconda3/lib/python3.7/site-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.feature_selection.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.feature_selection. Anything that cannot be imported from sklearn.feature_selection is now part of the private API.
#   warnings.warn(message, FutureWarning)
#
#
# -----
# DLATK Interface Initiated: 2020-11-16 06:54:24
# -----
# SQL QUERY: SELECT * FROM sywang_project.ags_cp
# ...

# %% [markdown]
# this creates the topics table
# feat$cat_ags_cp_w$msgs$message_id$1gra

# %%
feat_topics_table = 'feat$cat_ags_cp_w$threadheads$thread_id$1gra'

# %%
# %%sql
# select feat, sum(group_norm)/542 as popularity from {feat_topics_table}
# group by feat
# order by popularity desc
# limit 10
# Out:
#  * mysql://sywang@localhost/?charset=utf8mb4
# 10 rows affected.
# [('_intercept', 1.0),
#  ('19', 0.019674787930452107),
#  ('0', 0.01520218223181562),
#  ('29', 0.014867024779109516),
#  ('8', 0.0142718412116267),
#  ('1', 0.012911207731654965),
#  ('20', 0.011923942796892795),
#  ('16', 0.011183446091589166),
#  ('25', 0.011085273885385053),
#  ('2', 0.010235657535197246)]

# %%
# %%sql
# use {database};
# select category, group_concat(term order by weight desc separator ', ') as top_words from (
#     select category, term, weight,
#     @num := if(@type = category, @num + 1, 1) as row_number,
#     @type := category as dummy
#     from {topics_freq_table}
#     order by category, weight desc
# ) as x where x.row_number <= 10
# group by category
# having category like "19" or category like "0"  or category like "29" or category like "8" or category like "1";
# Out:
#  * mysql://sywang@localhost/?charset=utf8mb4
# 0 rows affected.
# 5 rows affected.
# [('0', 'practice, contact, interested, full, clinic, care, opportunity, email, position, feel'),
#  ('1', 'year, advice, history, thoughts, cell, beach, meds, slt, months, presented'),
#  ('8', 'ags, aao, members, questions, dear, link, society, org, american, committee'),
#  ('19', 'glaucoma, patient, specialist, recommendations, moving, area, center, dear, cataract, recommend'),
#  ('29', 'iop, years, ago, weeks, back, ahmed, week, bleb, post, retina')]
